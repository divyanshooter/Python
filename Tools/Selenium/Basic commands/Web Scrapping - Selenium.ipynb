# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html=f.read()

# %%
soup= BeautifulSoup(html,'lxml')

# %%
soup.prettify()
# Out:
# '<html class="way-item-finder" lang="en" style="--window-width: 1280;">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width" name="viewport"/>\n  <title>\n   Mobile Phones In Stock | Smartprix\n  </title>\n  <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <meta content="#4692F0" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="171761809591603" property="fb:app_id"/>\n  <link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/>\n  <meta content="Smartprix" property="og:site_name"/>\n  <meta content="@smartprix" name="twitter:site"/>\n  <meta content="@smartprix" name="twitter:creator"/>\n  <meta content="summary" name="twitter:card"/>\n  <link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/>\n  <script type="application/ld+json">\n   {"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://www.pinterest.com/smartprixcom/","https://x.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals","https://news.google.com/publications/CAAqBwgKMKe7jwswjemiAw","https://whatsapp.com/channel/0029Va91m7GAjPXHDPpBfW2o"],"logo":"https://www.smartprix.com/smartprix.png"}\n  </script>\n  <script type="application/ld+json">\n   {"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"OnePlus 13T","url":"https://www.smartprix.com/mobiles/oneplus-13t-ppd10prwqkga","image":["https://cdn1.smartprix.com/rx-i1rRn1XPA-w1200-h1200/1rRn1XPA.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"Vivo T4 5G","url":"https://www.smartprix.com/mobiles/vivo-t4-ppd186aae1n5","image":["https://cdn1.smartprix.com/rx-i84PZIN9q-w1200-h1200/84PZIN9q.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"Realme 14T 5G","url":"https://www.smartprix.com/mobiles/realme-14t-5g-ppd1tcwz558u","image":["https://cdn1.smartprix.com/rx-im8olEzQK-w1200-h1200/m8olEzQK.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"iQOO Z10 5G","url":"https://www.smartprix.com/mobiles/iqoo-z10-5g-ppd1aku7730p","image":["https://cdn1.smartprix.com/rx-i0WSqs965-w1200-h1200/0WSqs965.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"Motorola Edge 60 Stylus","url":"https://www.smartprix.com/mobiles/motorola-edge-60-stylus-ppd1wurw9siu","image":["https://cdn1.smartprix.com/rx-idCeQoeVJ-w1200-h1200/dCeQoeVJ.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Infinix Note 50s 5G","url":"https://www.smartprix.com/mobiles/infinix-note-50s-5g-ppd1x5xq88te","image":["https://cdn1.smartprix.com/rx-in4j1V5Zc-w1200-h1200/n4j1V5Zc.webp"]},{"@type":"ListItem","additionalType":"Product","position":7,"name":"Oppo K13","url":"https://www.smartprix.com/ ...

# %%
containers=soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []
for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-1-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df
# Out:
#                             model    price rating  \
# 0                      Vivo T4 5G  ₹21,999     81
# 1                   Realme 14T 5G  ₹17,999     82
# 2                     iQOO Z10 5G  ₹21,999     82
# 3         Motorola Edge 60 Stylus  ₹22,999     88
# 4             Infinix Note 50s 5G  ₹15,999     81
# 5                        Oppo K13  ₹17,999     80
# 6         Motorola Edge 60 Fusion  ₹25,999     86
# 7                       iQOO Z10x  ₹13,499    NaN
# 8           Samsung Galaxy M56 5G  ₹27,999     81
# 9                     Vivo T4x 5G  ₹14,646    NaN
# 10                   iQOO Neo 10R  ₹26,998     84
# 11                   Realme P3 5G  ₹16,315     80
# 12        Motorola Edge 50 Fusion  ₹19,499     85
# 13          Samsung Galaxy F55 5G  ₹17,397     86
# 14       Samsung Galaxy S24 FE 5G  ₹37,479     88
# 15                   Vivo V50e 5G  ₹28,999     83
# 16                    Vivo V50 5G  ₹34,999     85
# 17               Nothing Phone 3a  ₹23,438     85
# 18  Vivo T4 5G (12GB RAM + 256GB)  ₹25,999     83
# 19     Oppo K13 (8GB RAM + 256GB)  ₹19,999     80
#
#                                                sim  \
# 0   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 1               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 3    Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 4   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 5   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 6         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# 7   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 8               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 9   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 10  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 11         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12   Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 13         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 14   Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 15              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 16              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 17         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 19  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
#
#                                             processor  \
# 0    Snapdragon 7s Gen3, Octa Core, 2.5 GHz Processor
# 1        Dimensity 6300, Octa Core, 2.4 GHz Processor
# 2    Snapdragon 7s Gen3, Octa Core, 2.5 GHz Processor
# 3    Snapdragon 7s Gen2, Octa Core, 2.4 GHz Processor
# 4   Dimensity 7300 Ultimate, Octa Core, 2.5 GHz Pr...
# 5     Snapdragon 6 Gen4, Octa Core, 2.3 GHz Processor
# 6        Dimensity 7400, Octa Core, 2.5 GHz Processor
# 7        Dimensity 7300, Octa Core, 2.5 GHz Processor
# 8           Exynos 1480, Octa Core, 2.7 GHz Processor
# 9        Dimensity 7300, Octa Core, 2.5 GHz Processor
# 10     Snapdragon 8s Gen3, Octa Core, 3 GHz Processor
# 11    Snapdragon 6 Gen4, Octa Core, 2.3 GHz Processor
# 12   Snapdragon 7s Gen2, Octa Core, 2.4 GHz Processor
# 13    Snapdragon 7 Gen1, Octa Core, 2.4 GHz Processor
# 14        Exynos 2400e, Deca Core, 3.11 GHz Processor
# 15       Dimensity 7300, Octa Core, 2.5 GHz Processor
# 16   Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor
# 17   Snapdragon 7s Gen3, Octa Core, 2.5 GHz Processor
# 18   Snapdragon 7s Gen3, Octa Core, 2.5 GHz Processor
# 19    Snapdragon 6 Gen4, Octa Core, 2.3 GHz Processor
#
#                           ram                                  battery  \
# 0    8 GB RAM, 128 GB inbuilt  7300 mAh Battery with 90W Fast Charging
# 1    8 GB RAM, 128 GB inbuilt  6000 mAh Battery with 45W Fast Charging
# 2    8 GB RAM, 128 GB inbuilt  7300 mAh Battery with 90W Fast Charging
# 3    8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 68W Fast Charging
# 4    8 GB RAM, 128 GB inbuilt  5500 mAh Battery with 45W Fast Charging
# 5    8 GB RAM, 128 GB inbuilt  7000 mAh Battery with 80W Fast Charging
# 6    8 GB RAM, 256 GB inbuilt  5500 mAh Battery with 68W Fast Charging
# 7    6 GB RAM, 128 GB inbuilt  6500 mAh Battery with 44W Fast Charging
# 8    8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 45W Fast Charging
# 9    6 GB RAM, 128 GB inbuilt  6500 mAh Battery with 44W Fast Charging
# 10   8 GB RAM, 128 GB inbuilt  6400 mAh Battery with 80W Fast Charging
# 11   6 GB RAM, 128 GB inbuilt  6000 mAh Battery with 45W Fast Charging
# 12   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68W Fast Charging
# 13   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 45W Fast Charging
# 14   8 GB RAM, 128 GB inbuilt  4700 mAh Battery with 25W Fast Charging
# 15   8 GB RAM, 128 GB inbuilt  5600 mAh Battery with 90W Fast Charging
# 16   8 GB RAM, 128 GB inbuilt  6000 mAh Battery with 90W Fast Charging
# 17   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 50W Fast Charging
# 18  12 GB RAM, 256 GB inbuilt  7300 mAh Battery with 90W Fast Charging
# 19   8 GB RAM, 256 GB inbuilt  7000 mAh Battery with 80W Fast Charging
#
#                                               display  \
# 0   6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# 1   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 2   6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# 3   6.7 inches, 1220 x 2712 px, 120 Hz Display wit...
# 4   6.78 inches, 1080 x 2436 px, 144 Hz Display wi...
# 5   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 6   6.7 inches, 1220 x 2712 px, 120 Hz Display wit...
# 7   6.72 inches, 1080 x 2408 px, 120 Hz Display wi...
# 8   6.74 inches, 1080 x 2340 px, 120 Hz Display wi...
# 9   6.72 inches, 1080 x 2408 px, 120 Hz Display wi...
# 10  6.78 inches, 1260 x 2800 px, 144 Hz Display wi...
# 11  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 12  6.67 inches, 1080 x 2400 px, 144 Hz Display wi...
# 13  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 14  6.7 inches, 1080 x 2340 px, 120 Hz Display wit...
# 15  6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# 16  6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# 17  6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# 18  6.77 inches, 1080 x 2392 px, 120 Hz Display wi...
# 19  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
#
#                                                camera  \
# 0         50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 1         50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 2         50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 3        50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 4         64 MP + 2 MP Dual Rear & 13 MP Front Camera
# 5         50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 6        50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 7          50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 8   50 MP + 8 MP + 2 MP Triple Rear & 12 MP Front ...
# 9          50 MP + 2 MP Dual Rear & 8 MP Front Camera
# 10        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 11        50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 12       50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 13  50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# 14  50 MP + 12 MP + 8 MP Triple Rear & 10 MP Front...
# 15        50 MP + 8 MP Dual Rear & 50 MP Front Camera
# 16       50 MP + 50 MP Dual Rear & 50 MP Front Camera
# 17  50 MP + 50 MP + 8 MP Triple Rear & 32 MP Front...
# 18        50 MP + 2 MP Dual Rear & 32 MP Front Camera
# 19        50 MP + 2 MP Dual Rear & 16 MP Front Camera
#
#                                 card           os
# 0          Memory Card Not Supported  Android v15
# 1    Memory Card (Hybrid), upto 2 TB  Android v15
# 2          Memory Card Not Supported  Android v15
# 3   Memory Card Supported, upto 1 TB  Android v15
# 4                        Android v15    Bluetooth
# 5                        Android v15  No FM Radio
# 6    Memory Card (Hybrid), upto 1 TB  Android v15
# 7                        Android v15  No FM Radio
# 8                        Android v15  No FM Radio
# 9          Memory Card Not Supported  Android v15
# 10                       Android v15  No FM Radio
# 11                       Android v15  No FM Radio
# 12         Memory Card Not Supported  Android v14
# 13   Memory Card (Hybrid), upto 1 TB  Android v14
# 14         Memory Card Not Supported  Android v14
# 15         Memory Card Not Supported  Android v15
# 16         Memory Card Not Supported  Android v15
# 17                       Android v15  No FM Radio
# 18         Memory Card Not Supported  Android v15
# 19                       Android v15  No FM Radio

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      20 non-null     object
#  1   price      20 non-null     object
#  2   rating     18 non-null     object
#  3   sim        20 non-null     object
#  4   processor  20 non-null     object
#  5   ram        20 non-null     object
#  6   battery    20 non-null     object
#  7   display    20 non-null     object
#  8   camera     20 non-null     object
#  9   card       20 non-null     object
#  10  os         20 non-null     object
# dtypes: object(11)
# memory usage: 1.8+ KB
